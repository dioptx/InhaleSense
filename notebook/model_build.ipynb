# %% [markdown]
# # Model building 1
# ### In this file we will:
#
# 1. Build our model and train it.
# 2. Measure the accuracy of the model with the test set and save it.

# %%
import sys
import os
# Relative import enabling
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.processing import make_dataset
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Flatten
from tensorflow.python.keras.layers import LSTM

# %% [markdown]
# ## Hyperparameters:

# %%
# This is the size of the window that is fed into the DNN
window_size = 15
# The number of the features present in the dataset
num_of_features = 42
# Number of distinct labels in the output
label_length = 4
# Hyperparameter that defines the number of samples to work through
# before updating the internal model parameters.
batch_size = 25
# Epochs
ep = 100

# %% [markdown]
# ## Model creation & training:

# %%
# Create a model
model = Sequential()
model.add(LSTM(100, return_sequences=False, input_shape=(window_size, num_of_features)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(label_length, activation='softmax'))
model.compile(loss='binary_crossentropy',
                   optimizer='rmsprop',
                   metrics=['accuracy',])

# %%
data_train = make_dataset(window_size, num_of_features, label_length, test=False).batch(batch_size)
data_test = make_dataset(window_size, num_of_features, label_length, test=True).batch(batch_size)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0525 23:28:39.398243 4695860672 deprecation.py:323] From /Users/noresources/anaconda3/lib/python3.7/site-packages/tensorflow-2.0.0a0-py3.7-macosx-10.7-x86_64.egg/tensorflow/python/data/ops/dataset_ops.py:410: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.

# %%
model.fit(data_train, epochs=ep)
model.save('model_extended_{0}.h5'.format(ep))  # creates a HDF5 file 'my_model.h5'

# Evaluate the model on the test data using `evaluate`
print('\n# Evaluate on test data')
results = model.evaluate(data_test)
# Out:
# Epoch 1/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 253s 35ms/step - loss: 0.1524 - accuracy: 0.9479
# Epoch 2/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 235s 32ms/step - loss: 0.1383 - accuracy: 0.9547
# Epoch 3/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 220s 30ms/step - loss: 0.1410 - accuracy: 0.9547
# Epoch 4/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 214s 30ms/step - loss: 0.1461 - accuracy: 0.9540
# Epoch 5/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 222s 31ms/step - loss: 0.1469 - accuracy: 0.9547
# Epoch 6/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 221s 31ms/step - loss: 0.1481 - accuracy: 0.9547
# Epoch 7/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 221s 31ms/step - loss: 0.1501 - accuracy: 0.9547
# Epoch 8/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 222s 31ms/step - loss: 0.1526 - accuracy: 0.9544
# Epoch 9/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 221s 31ms/step - loss: 0.1573 - accuracy: 0.9535
# Epoch 10/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 212s 29ms/step - loss: 0.1570 - accuracy: 0.9535
# Epoch 11/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 201s 28ms/step - loss: 0.1554 - accuracy: 0.9548
# Epoch 12/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 202s 28ms/step - loss: 0.1604 - accuracy: 0.9535
# Epoch 13/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 203s 28ms/step - loss: 0.1576 - accuracy: 0.9535
# Epoch 14/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 201s 28ms/step - loss: 0.1619 - accuracy: 0.9530
# Epoch 15/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 202s 28ms/step - loss: 0.1684 - accuracy: 0.9525
# Epoch 16/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 201s 28ms/step - loss: 0.1633 - accuracy: 0.9532
# Epoch 17/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 201s 28ms/step - loss: 0.
100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1960 - accuracy: 0.9520
# Epoch 56/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 196s 27ms/step - loss: 0.1947 - accuracy: 0.9523
# Epoch 57/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1952 - accuracy: 0.9512
# Epoch 58/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 196s 27ms/step - loss: 0.1951 - accuracy: 0.9521
# Epoch 59/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1927 - accuracy: 0.9511
# Epoch 60/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 196s 27ms/step - loss: 0.1968 - accuracy: 0.9511
# Epoch 61/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1902 - accuracy: 0.9507
# Epoch 62/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1930 - accuracy: 0.9521
# Epoch 63/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1941 - accuracy: 0.9517
# Epoch 64/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1957 - accuracy: 0.9521
# Epoch 65/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 196s 27ms/step - loss: 0.1903 - accuracy: 0.9507
# Epoch 66/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 196s 27ms/step - loss: 0.1925 - accuracy: 0.9519
# Epoch 67/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 199s 27ms/step - loss: 0.1965 - accuracy: 0.9516
# Epoch 68/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1943 - accuracy: 0.9520
# Epoch 69/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1902 - accuracy: 0.9519
# Epoch 70/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1898 - accuracy: 0.9526
# Epoch 71/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1894 - accuracy: 0.9521
# Epoch 72/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1907 - accuracy: 0.9520
# Epoch 73/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1985 - accuracy: 0.9520
# Epoch 74/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1952 - accuracy: 0.9507
# Epoch 75/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 196s 27ms/step - loss: 0.1957 - accuracy: 0.9514
# Epoch 76/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1914 - accuracy: 0.9517
# Epoch 77/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1955 - accuracy: 0.9503
# Epoch 78/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1921 - accuracy: 0.9517
# Epoch 79/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1949 - accuracy: 0.9511
# Epoch 80/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1952 - accuracy: 0.9502
# Epoch 81/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1917 - accuracy: 0.9514
# Epoch 82/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1919 - accuracy: 0.9526
# Epoch 83/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 196s 27ms/step - loss: 0.1993 - accuracy: 0.9516
# Epoch 84/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1921 - accuracy: 0.9511
# Epoch 85/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 199s 28ms/step - loss: 0.1943 - accuracy: 0.9502
# Epoch 86/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1951 - accuracy: 0.9517
# Epoch 87/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 196s 27ms/step - loss: 0.1932 - accuracy: 0.9512
# Epoch 88/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1965 - accuracy: 0.9511
# Epoch 89/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1916 - accuracy: 0.9516
# Epoch 90/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.2004 - accuracy: 0.9506
# Epoch 91/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.2015 - accuracy: 0.9518
# Epoch 92/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1973 - accuracy: 0.9517
# Epoch 93/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 196s 27ms/step - loss: 0.1982 - accuracy: 0.9512
# Epoch 94/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.2044 - accuracy: 0.9500
# Epoch 95/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.2050 - accuracy: 0.9497
# Epoch 96/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.2077 - accuracy: 0.9506
# Epoch 97/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.2038 - accuracy: 0.9516
# Epoch 98/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.2027 - accuracy: 0.9517
# Epoch 99/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 198s 27ms/step - loss: 0.1923 - accuracy: 0.9517
# Epoch 100/100
# Dataset created with 180857 entries
# 7235/7235 [==============================] - 197s 27ms/step - loss: 0.1951 - accuracy: 0.9513
#
# # Evaluate on test data
# Dataset created with 45215 entries
#    1809/Unknown - 15s 8ms/step - loss: 0.2298 - accuracy: 0.9454
